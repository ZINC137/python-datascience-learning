# %%
import pandas as pd

# %%
df = pd.read_csv('imf_indicators.csv')

# %%
df
# Out:
#      country_code  year  current_account_pct_gdp  gdp_usd_bn  gdp_growth_pct  \
# 0             ABW  2010                    -18.7       2.454            -3.3
# 1             ABW  2011                    -10.0       2.638             3.6
# 2             ABW  2012                      3.6       2.615            -1.2
# 3             ABW  2013                    -12.0       2.728             7.1
# 4             ABW  2014                     -4.8       2.791             1.4
# ...           ...   ...                      ...         ...             ...
# 3178          ZWE  2019                      2.3      39.776            -6.3
# 3179          ZWE  2020                      1.7      39.962            -7.8
# 3180          ZWE  2021                      0.7      52.413             8.5
# 3181          ZWE  2022                      0.6      48.570             6.1
# 3182          ZWE  2023                      0.3      44.372             5.3
#
# ...

# %%
df.shape
# Out:
# (3183, 10)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3183 entries, 0 to 3182
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   country_code             3183 non-null   str
#  1   year                     3183 non-null   int64
#  2   current_account_pct_gdp  3129 non-null   float64
#  3   gdp_usd_bn               3183 non-null   float64
#  4   gdp_growth_pct           3180 non-null   float64
#  5   inflation_avg_pct        3158 non-null   float64
#  6   unemployment_pct         1644 non-null   float64
#  7   govt_gross_debt_gdp      3145 non-null   float64
#  8   population_millions      3182 non-null   float64
#  9   source_engine            3183 non-null   str
# dtypes: float64(7), int64(1), str(2)
# memory usage: 248.8 KB

# %%
pd.set_option('display.max_columns',10)

# %%
df
# Out:
#      country_code  year  current_account_pct_gdp  gdp_usd_bn  gdp_growth_pct  \
# 0             ABW  2010                    -18.7       2.454            -3.3
# 1             ABW  2011                    -10.0       2.638             3.6
# 2             ABW  2012                      3.6       2.615            -1.2
# 3             ABW  2013                    -12.0       2.728             7.1
# 4             ABW  2014                     -4.8       2.791             1.4
# ...           ...   ...                      ...         ...             ...
# 3178          ZWE  2019                      2.3      39.776            -6.3
# 3179          ZWE  2020                      1.7      39.962            -7.8
# 3180          ZWE  2021                      0.7      52.413             8.5
# 3181          ZWE  2022                      0.6      48.570             6.1
# 3182          ZWE  2023                      0.3      44.372             5.3
#
# ...

# %%
df
# Out:
#      country_code  year  current_account_pct_gdp  gdp_usd_bn  gdp_growth_pct  \
# 0             ABW  2010                    -18.7       2.454            -3.3
# 1             ABW  2011                    -10.0       2.638             3.6
# 2             ABW  2012                      3.6       2.615            -1.2
# 3             ABW  2013                    -12.0       2.728             7.1
# 4             ABW  2014                     -4.8       2.791             1.4
# ...           ...   ...                      ...         ...             ...
# 3178          ZWE  2019                      2.3      39.776            -6.3
# 3179          ZWE  2020                      1.7      39.962            -7.8
# 3180          ZWE  2021                      0.7      52.413             8.5
# 3181          ZWE  2022                      0.6      48.570             6.1
# 3182          ZWE  2023                      0.3      44.372             5.3
#
# ...

# %%
df.tail(10)
# Out:
#      country_code  year  current_account_pct_gdp  gdp_usd_bn  gdp_growth_pct  \
# 3173          ZWE  2014                     -8.3      28.248             2.4
# 3174          ZWE  2015                     -5.7      28.123             1.8
# 3175          ZWE  2016                     -2.4      29.257             0.8
# 3176          ZWE  2017                     -0.9      31.018             5.2
# 3177          ZWE  2018                     -2.6      53.914             5.0
# 3178          ZWE  2019                      2.3      39.776            -6.3
# 3179          ZWE  2020                      1.7      39.962            -7.8
# 3180          ZWE  2021                      0.7      52.413             8.5
# 3181          ZWE  2022                      0.6      48.570             6.1
# 3182          ZWE  2023                      0.3      44.372             5.3
#
#       inflation_avg_pct  unemployment_pct  govt_gross_debt_gdp  \
# ...

# %%
df.iloc[[0,1,2],0:5]
# Out:
#   country_code  year  current_account_pct_gdp  gdp_usd_bn  gdp_growth_pct
# 0          ABW  2010                    -18.7       2.454            -3.3
# 1          ABW  2011                    -10.0       2.638             3.6
# 2          ABW  2012                      3.6       2.615            -1.2

# %%
df.loc[0:2,['country_code','year']]
# Out:
#   country_code  year
# 0          ABW  2010
# 1          ABW  2011
# 2          ABW  2012

# %%
df.set_index('year')
# Out:
#      country_code  current_account_pct_gdp  gdp_usd_bn  gdp_growth_pct  \
# year
# 2010          ABW                    -18.7       2.454            -3.3
# 2011          ABW                    -10.0       2.638             3.6
# 2012          ABW                      3.6       2.615            -1.2
# 2013          ABW                    -12.0       2.728             7.1
# 2014          ABW                     -4.8       2.791             1.4
# ...           ...                      ...         ...             ...
# 2019          ZWE                      2.3      39.776            -6.3
# 2020          ZWE                      1.7      39.962            -7.8
# 2021          ZWE                      0.7      52.413             8.5
# 2022          ZWE                      0.6      48.570             6.1
# 2023          ZWE                      0.3      44.372             5.3
#
#       inflation_avg_pct  unemployment_pct  govt_gross_debt_gdp  \
# year
# ...

# %%
df
# Out:
#      country_code  year  current_account_pct_gdp  gdp_usd_bn  gdp_growth_pct  \
# 0             ABW  2010                    -18.7       2.454            -3.3
# 1             ABW  2011                    -10.0       2.638             3.6
# 2             ABW  2012                      3.6       2.615            -1.2
# 3             ABW  2013                    -12.0       2.728             7.1
# 4             ABW  2014                     -4.8       2.791             1.4
# ...           ...   ...                      ...         ...             ...
# 3178          ZWE  2019                      2.3      39.776            -6.3
# 3179          ZWE  2020                      1.7      39.962            -7.8
# 3180          ZWE  2021                      0.7      52.413             8.5
# 3181          ZWE  2022                      0.6      48.570             6.1
# 3182          ZWE  2023                      0.3      44.372             5.3
#
# ...

# %%
df.set_index('year', inplace= True)

# %%
df
# Out:
#      country_code  current_account_pct_gdp  gdp_usd_bn  gdp_growth_pct  \
# year
# 2010          ABW                    -18.7       2.454            -3.3
# 2011          ABW                    -10.0       2.638             3.6
# 2012          ABW                      3.6       2.615            -1.2
# 2013          ABW                    -12.0       2.728             7.1
# 2014          ABW                     -4.8       2.791             1.4
# ...           ...                      ...         ...             ...
# 2019          ZWE                      2.3      39.776            -6.3
# 2020          ZWE                      1.7      39.962            -7.8
# 2021          ZWE                      0.7      52.413             8.5
# 2022          ZWE                      0.6      48.570             6.1
# 2023          ZWE                      0.3      44.372             5.3
#
#       inflation_avg_pct  unemployment_pct  govt_gross_debt_gdp  \
# year
# ...

# %%
df.sort_index(ascending = False, inplace=True)

# %%
df
# Out:
#      country_code  current_account_pct_gdp  gdp_usd_bn  gdp_growth_pct  \
# year
# 2023          LBR                    -20.1       4.390             4.6
# 2023          EUQ                      2.0   26028.485             1.2
# 2023          IND                     -0.7    3500.906             7.2
# 2023          IDN                     -0.1    1371.167             5.0
# 2023          HUN                     -0.1     213.315            -0.8
# ...           ...                      ...         ...             ...
# 2010          JPN                      3.8    5811.577             4.1
# 2010          KAZ                      1.8     148.047             7.3
# 2010          TUR                     -5.7     783.025             8.5
# 2010          KEN                     -5.2      45.406             8.1
# 2010          ABW                    -18.7       2.454            -3.3
#
#       inflation_avg_pct  unemployment_pct  govt_gross_debt_gdp  \
# year
# ...

# %%
df.reset_index(inplace=True)

# %%
df.columns
# Out:
# Index(['year', 'country_code', 'current_account_pct_gdp', 'gdp_usd_bn',
#        'gdp_growth_pct', 'inflation_avg_pct', 'unemployment_pct',
#        'govt_gross_debt_gdp', 'population_millions', 'source_engine'],
#       dtype='str')

# %%
filt = (df['year'].isin([2010, 2023]) & (df['gdp_growth_pct'] >= 5))

# %%
df.loc[filt, 'source_engine'].count()
# Out:
# np.int64(164)

# %%
df.rename(columns = {'country_code':'CC'},inplace= True)

# %%
df.CC
# Out:
# 0       LBR
# 1       EUQ
# 2       IND
# 3       IDN
# 4       HUN
#        ...
# 3178    JPN
# 3179    KAZ
# 3180    TUR
# 3181    KEN
# 3182    ABW
# Name: CC, Length: 3183, dtype: str

# %%
df.CC = df.CC.replace({'IND':'BHA'})

# %%
df
# Out:
#       year   CC  current_account_pct_gdp  gdp_usd_bn  gdp_growth_pct  \
# 0     2023  LBR                    -20.1       4.390             4.6
# 1     2023  EUQ                      2.0   26028.485             1.2
# 2     2023  BHA                     -0.7    3500.906             7.2
# 3     2023  IDN                     -0.1    1371.167             5.0
# 4     2023  HUN                     -0.1     213.315            -0.8
# ...    ...  ...                      ...         ...             ...
# 3178  2010  JPN                      3.8    5811.577             4.1
# 3179  2010  KAZ                      1.8     148.047             7.3
# 3180  2010  TUR                     -5.7     783.025             8.5
# 3181  2010  KEN                     -5.2      45.406             8.1
# 3182  2010  ABW                    -18.7       2.454            -3.3
#
#       inflation_avg_pct  unemployment_pct  govt_gross_debt_gdp  \
# 0                  10.1               NaN                 57.2
# ...

# %%
df.sort_values(by='year',ascending=True)
# Out:
#       year   CC  current_account_pct_gdp  gdp_usd_bn  gdp_growth_pct  \
# 3182  2010  ABW                    -18.7       2.454            -3.3
# 3037  2010  TCD                     -2.9      14.070            13.8
# 3036  2010  MNG                    -12.3       7.185             7.3
# 3035  2010  NOR                     11.4     440.133             1.0
# 3034  2010  NMQ                     -2.8   17870.126             2.9
# ...    ...  ...                      ...         ...             ...
# 146   2023  TUR                     -3.6    1153.295             5.0
# 145   2023  VEN                      5.8     102.378             4.0
# 144   2023  VUT                     -7.8       1.198             5.8
# 142   2023   WE                     -1.2    6614.744             2.3
# 0     2023  LBR                    -20.1       4.390             4.6
#
#       inflation_avg_pct  unemployment_pct  govt_gross_debt_gdp  \
# 3182                2.1              10.6                 54.7
# ...

# %%
df.nlargest(10,'gdp_growth_pct')
# Out:
#       year   CC  current_account_pct_gdp  gdp_usd_bn  gdp_growth_pct  \
# 2623  2012  LBY                     25.8      92.542            86.8
# 53    2023  MAC                     31.4      45.627            75.3
# 310   2022  GUY                     25.9      14.718            63.3
# 736   2020  GUY                    -17.3       5.471            43.5
# 571   2021  MDV                     -8.7       5.240            37.5
# 9     2023  GUY                      9.9      16.919            33.8
# 1404  2017  LBY                      6.6      67.153            32.5
# 2275  2014  ERI                     17.7       2.604            30.9
# 621   2021  LBY                     11.4      35.216            27.3
# 2466  2013  SSD                     -3.9      14.947            27.3
#
#       inflation_avg_pct  unemployment_pct  govt_gross_debt_gdp  \
# 2623                6.1               NaN                  NaN
# 53                  0.9               2.7                  0.0
# ...

# %%
country_grp = df.groupby('CC')

# %%
country_grp.groups
# Out:
# {'ABW': [225, 415, 504, 851, 943, 1253, 1580, 1749, 1956, 2099, 2289, 2504, 2944, 3182], 'ADVEC': [222, 445, 575, 774, 1021, 1167, 1588, 1747, 1899, 2185, 2431, 2516, 2738, 3127], 'AFG': [213, 366, 529, 780, 1076, 1289, 1574, 1653, 2042, 2165, 2340, 2508, 2922, 3154], 'AFQ': [215, 253, 560, 873, 915, 1307, 1401, 1601, 1980, 2083, 2334, 2521, 2899, 3079], 'AGO': [221, 432, 494, 845, 1112, 1279, 1469, 1617, 2045, 2048, 2326, 2686, 2885, 3065], 'ALB': [212, 248, 540, 776, 1125, 1145, 1521, 1597, 1841, 2077, 2395, 2705, 2836, 3089], 'AND': [216, 236, 670, 757, 1056, 1158, 1585, 1660, 1859, 2214, 2474, 2580, 2851, 3028], 'APQ': [219, 394, 552, 709, 1078, 1139, 1367, 1671, 1939, 2183, 2346, 2641, 2911, 3050], 'ARE': [223, 263, 555, 811, 1029, 1326, 1389, 1767, 1967, 2272, 2327, 2622, 2906, 3157], 'ARG': [218, 299, 675, 783, 1061, 1136, 1533, 1765, 2007, 2201, 2375, 2645, 2732, 3177], 'ARM': [217, 229, 526, 753, 946, 1312, 1468, 1721, 1912, 2168, 2485, 2599, 2774, 3117], 'AS5': [220, 391, 5
# ...

# %%
country_grp['year'].value_counts().loc['BHA']
# Out:
# year
# 2011    1
# 2013    1
# 2023    1
# 2016    1
# 2015    1
# 2021    1
# 2010    1
# 2014    1
# 2020    1
# 2019    1
# 2012    1
# 2018    1
# 2017    1
# 2022    1
# Name: count, dtype: int64

# %%
df.head(50)
# Out:
#     year   CC  current_account_pct_gdp  gdp_usd_bn  gdp_growth_pct  \
# 0   2023  LBR                    -20.1       4.390             4.6
# 1   2023  EUQ                      2.0   26028.485             1.2
# 2   2023  BHA                     -0.7    3500.906             7.2
# 3   2023  IDN                     -0.1    1371.167             5.0
# 4   2023  HUN                     -0.1     213.315            -0.8
# 5   2023  HTI                     -3.5      19.603            -1.9
# 6   2023  HRV                      0.1      85.647             3.8
# 7   2023  HND                     -4.0      34.356             3.6
# 8   2023  HKG                      8.4     380.762             3.2
# 9   2023  GUY                      9.9      16.919            33.8
# 10  2023  GTM                      3.1     104.354             3.5
# 11  2023  GRD                    -20.3       1.336             4.5
# 12  2023  GRC                     -6.8     243.016             2.1
# ...

# %%
filt = (df.CC == 'JAM')

# %%
filt.value_counts()
# Out:
# CC
# False    3169
# True       14
# Name: count, dtype: int64

# %%
country_grp.get_group('JAM')
# Out:
#       year   CC  current_account_pct_gdp  gdp_usd_bn  gdp_growth_pct  \
# 48    2023  JAM                      2.7      21.299             2.7
# 279   2022  JAM                     -0.7      18.710             6.4
# 590   2021  JAM                      0.9      15.982             5.7
# 741   2020  JAM                     -1.0      15.079            -8.3
# 1014  2019  JAM                     -1.8      17.002             1.8
# 1197  2018  JAM                     -1.4      16.767             2.5
# 1557  2017  JAM                     -2.5      15.726             2.3
# 1695  2016  JAM                     -0.3      14.931             2.8
# 2031  2015  JAM                     -2.9      14.927             1.4
# 2227  2014  JAM                     -7.8      14.225             0.6
# 2284  2013  JAM                     -9.3      14.582             0.2
# 2650  2012  JAM                     -9.5      15.149            -0.5
# 2731  2011  JAM                    -13.3      14.787             1.4
# ...

# %%
country_grp.gdp_growth_pct.median()
# Out:
# CC
# ABW      3.35
# ADVEC    2.05
# AFG      2.45
# AFQ      3.50
# AGO      1.70
#          ...
# WSM      1.85
# YEM      0.30
# ZAF      1.50
# ZMB      4.90
# ZWE      5.10
# Name: gdp_growth_pct, Length: 229, dtype: float64

# %%
country_grp.gdp_growth_pct.median().loc['JAM']
# Out:
# np.float64(1.6)

# %%
country_grp.gdp_growth_pct.agg(['median','mean'])
# Out:
#        median      mean
# CC
# ABW      3.35  2.185714
# ADVEC    2.05  1.978571
# AFG      2.45  1.957143
# AFQ      3.50  3.428571
# AGO      1.70  2.057143
# ...       ...       ...
# WSM      1.85  2.135714
# YEM      0.30 -2.522222
# ZAF      1.50  1.371429
# ZMB      4.90  4.492857
# ZWE      5.10  5.285714
#
# [229 rows x 2 columns]
