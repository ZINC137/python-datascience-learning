# %%
import numpy as np

# %%
arr1 = np.array([[1,3,5],
                 [3,6,4],
                 [4,5,2]])
arr2 = np.array([[1,5,5],
                 [5,3,7],
                 [4,5,6]])
arr3 = np.array([[1,3,5,6],
                 [3,6,4,5],
                 [4,5,2,3]])

# %%
arr1 + arr2
# Out:
# array([[ 2,  8, 10],
#        [ 8,  9, 11],
#        [ 8, 10,  8]])

# %%
arr1 * arr2
# Out:
# array([[ 1, 15, 25],
#        [15, 18, 28],
#        [16, 25, 12]])

# %%
arr1.dot(arr2)
# Out:
# array([[36, 39, 56],
#        [49, 53, 81],
#        [37, 45, 67]])

# %%
arr2.dot(arr1)
# Out:
# array([[36, 58, 35],
#        [42, 68, 51],
#        [43, 72, 52]])

# %%
arr = np.array([2,6,4,5,7])

# %%
arr[:2]
# Out:
# array([2, 6])

# %%
arr1
# Out:
# array([[1, 3, 5],
#        [3, 6, 4],
#        [4, 5, 2]])

# %%
arr1[ :,1:2]
# Out:
# array([[3],
#        [6],
#        [5]])

# %%
arr1[1:2,1:2]
# Out:
# array([[6]])

# %%
arr1[1:,1:]
# Out:
# array([[6, 4],
#        [5, 2]])
