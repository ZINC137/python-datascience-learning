# %%
import numpy as np

# %%
arr = np.random.random((4,3))

# %%
np.random.random()
# Out:
# 0.18790020534024154

# %%
if np.random.random() > 0.5:
  print("correct")
else:
  print("wrong")
# Out:
# correct

# %%
np.arange(1,10,3)
# Out:
# array([1, 4, 7])

# %%
np.linspace(1,5,9)
# Out:
# array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
arr
# Out:
# array([[0.1762239 , 0.94568537, 0.79448532],
#        [0.12030214, 0.81197815, 0.58173881],
#        [0.29522197, 0.46815658, 0.89816807],
#        [0.70151817, 0.57469818, 0.57258648]])

# %%
np.reshape(arr,(3,4))
# Out:
# array([[0.1762239 , 0.94568537, 0.79448532, 0.12030214],
#        [0.81197815, 0.58173881, 0.29522197, 0.46815658],
#        [0.89816807, 0.70151817, 0.57469818, 0.57258648]])

# %%
arr.flatten()
# Out:
# array([0.1762239 , 0.94568537, 0.79448532, 0.12030214, 0.81197815,
#        0.58173881, 0.29522197, 0.46815658, 0.89816807, 0.70151817,
#        0.57469818, 0.57258648])
