# %%
import numpy as np

# %%
arr = np.array([2,5,3,4,6,4,5,12])

# %%
arr
# Out:
# array([ 2,  5,  3,  4,  6,  4,  5, 12])

# %%
arr[5]
# Out:
# np.int64(4)

# %%
arr[4:]
# Out:
# array([ 6,  4,  5, 12])

# %%
arr[:3]
# Out:
# array([2, 5, 3])

# %%
arr[2:5]
# Out:
# array([3, 4, 6])

# %%
arr = np.array([[2,4,5,6],[4,3,5,7],[5,3,4,8]])

# %%
arr
# Out:
# array([[2, 4, 5, 6],
#        [4, 3, 5, 7],
#        [5, 3, 4, 8]])

# %%
arr[2,3]
# Out:
# np.int64(8)

# %%
arr[ : , 1:2]
# Out:
# array([[4],
#        [3],
#        [3]])

# %%
arr[1:2,:3]
# Out:
# array([[4, 3, 5]])

# %%
arr[1:,2:]
# Out:
# array([[5, 7],
#        [4, 8]])
