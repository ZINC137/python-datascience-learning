# %%
import numpy as np

# %%
arr1 = np.array([[1,4,23,5],[4,5,3,8]])
arr2 = np.array([[2,5,4,3],[4,6,3,5]])

# %%
arr1,arr2
# Out:
# (array([[ 1,  4, 23,  5],
#         [ 4,  5,  3,  8]]),
#  array([[2, 5, 4, 3],
#         [4, 6, 3, 5]]))

# %%
np.vstack((arr2,arr1))
# Out:
# array([[ 2,  5,  4,  3],
#        [ 4,  6,  3,  5],
#        [ 1,  4, 23,  5],
#        [ 4,  5,  3,  8]])

# %%
np.hstack((arr1,arr2))
# Out:
# array([[ 1,  4, 23,  5,  2,  5,  4,  3],
#        [ 4,  5,  3,  8,  4,  6,  3,  5]])

# %%
arr3 =np.concatenate((arr1,arr2),axis=0)

# %%
arr3
# Out:
# array([[ 1,  4, 23,  5],
#        [ 4,  5,  3,  8],
#        [ 2,  5,  4,  3],
#        [ 4,  6,  3,  5]])

# %%
np.hsplit(arr3,4)
# Out:
# [array([[1],
#         [4],
#         [2],
#         [4]]),
#  array([[4],
#         [5],
#         [5],
#         [6]]),
#  array([[23],
#         [ 3],
#         [ 4],
#         [ 3]]),
#  array([[5],
#         [8],
#         [3],
#         [5]])]

# %%
np.vsplit(arr3,2)
# Out:
# [array([[ 1,  4, 23,  5],
#         [ 4,  5,  3,  8]]),
#  array([[2, 5, 4, 3],
#         [4, 6, 3, 5]])]
