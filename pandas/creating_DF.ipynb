# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
people['email']
# Out:
# ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
type(df['email'])
# Out:
# pandas.Series

# %%
df[['last', 'email']]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 1      Doe        JaneDoe@email.com
# 2      Doe        JohnDoe@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
df.iloc[[0,1],[1,2]]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 1      Doe        JaneDoe@email.com

# %%
df.reset_index()
# Out:
#    index  first     last                    email
# 0      0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1      1   Jane      Doe        JaneDoe@email.com
# 2      2   John      Doe        JohnDoe@email.com

# %%
df.set_index('first')
# Out:
#           last                    email
# first
# Corey  Schafer  CoreyMSchafer@gmail.com
# Jane       Doe        JaneDoe@email.com
# John       Doe        JohnDoe@email.com

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.set_index('first', inplace = True)

# %%
df
# Out:
#           last                    email
# first
# Corey  Schafer  CoreyMSchafer@gmail.com
# Jane       Doe        JaneDoe@email.com
# John       Doe        JohnDoe@email.com

# %%
df.reset_index()
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df
# Out:
#           last                    email
# first
# Corey  Schafer  CoreyMSchafer@gmail.com
# Jane       Doe        JaneDoe@email.com
# John       Doe        JohnDoe@email.com

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
filt = (df['last'] == 'Doe') | (df['first'] == 'john')

# %%
df.loc[filt, 'email']
# Out:
# 1    JaneDoe@email.com
# 2    JohnDoe@email.com
# Name: email, dtype: str

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.columns = (x.upper() for x in df.columns)
df
# Out:
#    FIRST     LAST                    EMAIL
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.rename(columns= {'FIRST':'first'})
# Out:
#    first     LAST                    EMAIL
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df
# Out:
#    FIRST     LAST                    EMAIL
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.columns.str.lower()
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
df
# Out:
#    FIRST     LAST                    EMAIL
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.columns = (x.lower() for x in df.columns)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[3] = ['anna','beckham','anna34@email.com']

# %%
df.replace({'John' : 'Johnny'},inplace=True)
# Out:
#     first     last                    email
# 0   Corey  Schafer  CoreyMSchafer@gmail.com
# 1    Jane      Doe        JaneDoe@email.com
# 2  Johnny      Doe        JohnDoe@email.com
# 3    anna  beckham         anna34@email.com

# %%
df
# Out:
#     first     last                    email
# 0   Corey  Schafer  CoreyMSchafer@gmail.com
# 1    Jane      Doe        JaneDoe@email.com
# 2  Johnny      Doe        JohnDoe@email.com
# 3    anna  beckham         anna34@email.com

# %%
df.loc[2,'first'] = 'John'

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   anna  beckham         anna34@email.com

# %%
df.drop(3)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   anna  beckham         anna34@email.com

# %%
df.email = df.email.str.lower()

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John      Doe        johndoe@email.com
# 3   anna  beckham         anna34@email.com

# %%
df.email.apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# 3    16
# Name: email, dtype: int64

# %%
def update_email(email) :
    return email.upper()

# %%
df.email = df.email.apply(update_email)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  COREYMSCHAFER@GMAIL.COM
# 1   Jane      Doe        JANEDOE@EMAIL.COM
# 2   John      Doe        JOHNDOE@EMAIL.COM
# 3   anna  beckham         ANNA34@EMAIL.COM

# %%
df.email = df.email.apply(lambda x : x.lower())

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John      Doe        johndoe@email.com
# 3   anna  beckham         anna34@email.com

# %%
df.apply(len, axis = 'columns')
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# dtype: int64

# %%
df.map(len)
# Out:
#    first  last  email
# 0      5     7     23
# 1      4     3     17
# 2      4     3     17
# 3      4     7     16

# %%
df.map(str.lower)
# Out:
#    first     last                    email
# 0  corey  schafer  coreymschafer@gmail.com
# 1   jane      doe        janedoe@email.com
# 2   john      doe        johndoe@email.com
# 3   anna  beckham         anna34@email.com

# %%
df.first.map({'Corey':'chris'})
# Out:
# 0    chris
# 1      NaN
# 2      NaN
# 3      NaN
# Name: first, dtype: str

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John      Doe        johndoe@email.com
# 3   anna  beckham         anna34@email.com

# %%
df['full_name'] = df.first + ' ' + df.last

# %%
df
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  coreymschafer@gmail.com  Corey Schafer
# 1   Jane      Doe        janedoe@email.com       Jane Doe
# 2   John      Doe        johndoe@email.com       John Doe
# 3   anna  beckham         anna34@email.com   anna beckham

# %%
df.drop(columns=['first','last'], inplace=True)

# %%
df
# Out:
#                      email      full_name
# 0  coreymschafer@gmail.com  Corey Schafer
# 1        janedoe@email.com       Jane Doe
# 2        johndoe@email.com       John Doe
# 3         anna34@email.com   anna beckham

# %%
df['full_name'].str.split(' ', expand=True)
# Out:
#        0        1
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John      Doe
# 3   anna  beckham

# %%
df[['first','last']] = df['full_name'].str.split(' ', expand=True)

# %%
df
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        janedoe@email.com       Jane Doe   Jane      Doe
# 2        johndoe@email.com       John Doe   John      Doe
# 3         anna34@email.com   anna beckham   anna  beckham

# %%
col1 = df.pop('first')
df.insert(0,'first',col1)

# %%
df
# Out:
#    first                    email      full_name     last
# 0  Corey  coreymschafer@gmail.com  Corey Schafer  Schafer
# 1   Jane        janedoe@email.com       Jane Doe      Doe
# 2   John        johndoe@email.com       John Doe      Doe
# 3   anna         anna34@email.com   anna beckham  beckham

# %%
col2 = df.pop('last')
df.insert(1,'last',col2)

# %%
df
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  coreymschafer@gmail.com  Corey Schafer
# 1   Jane      Doe        janedoe@email.com       Jane Doe
# 2   John      Doe        johndoe@email.com       John Doe
# 3   anna  beckham         anna34@email.com   anna beckham

# %%
df.replace({'anna':'Anna'},inplace=True)
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  coreymschafer@gmail.com  Corey Schafer
# 1   Jane      Doe        janedoe@email.com       Jane Doe
# 2   John      Doe        johndoe@email.com       John Doe
# 3   Anna  beckham         anna34@email.com   anna beckham

# %%
df.sort_values(by = ['last'],ascending=[True])
# Out:
#    first     last                    email      full_name
# 1   Jane      Doe        janedoe@email.com       Jane Doe
# 2   John      Doe        johndoe@email.com       John Doe
# 0  Corey  Schafer  coreymschafer@gmail.com  Corey Schafer
# 3   Anna  beckham         anna34@email.com   anna beckham

# %%
df
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  coreymschafer@gmail.com  Corey Schafer
# 1   Jane      Doe        janedoe@email.com       Jane Doe
# 2   John      Doe        johndoe@email.com       John Doe
# 3   Anna  beckham         anna34@email.com   anna beckham

# %%
df.sort_values(by=['first','last'],ascending=[True, False],inplace=True)

# %%
df
# Out:
#    first     last                    email      full_name
# 3   Anna  beckham         anna34@email.com   anna beckham
# 0  Corey  Schafer  coreymschafer@gmail.com  Corey Schafer
# 1   Jane      Doe        janedoe@email.com       Jane Doe
# 2   John      Doe        johndoe@email.com       John Doe

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  coreymschafer@gmail.com  Corey Schafer
# 1   Jane      Doe        janedoe@email.com       Jane Doe
# 2   John      Doe        johndoe@email.com       John Doe
# 3   Anna  beckham         anna34@email.com   anna beckham

# %%
df.last.sort_values()
# Out:
# 1        Doe
# 2        Doe
# 0    Schafer
# 3    beckham
# Name: last, dtype: str

# %%
last_group = df.groupby('last')

# %%
last_group.groups
# Out:
# {'Doe': [1, 2], 'Schafer': [0], 'beckham': [3]}

# %%
last_group.get_group('Doe')
# Out:
#   first last              email full_name
# 1  Jane  Doe  janedoe@email.com  Jane Doe
# 2  John  Doe  johndoe@email.com  John Doe

# %%
last_group['full_name'].value_counts
# Out:
# <bound method SeriesGroupBy.value_counts of <pandas.api.typing.SeriesGroupBy object at 0x127e4bd50>>
