# %%
import numpy as np

# %%
arr = np.array([[2,3,45,32,56],[5,7,2,4,8],[6,3,2,8,9]])

# %%
arr
# Out:
# array([[ 2,  3, 45, 32, 56],
#        [ 5,  7,  2,  4,  8],
#        [ 6,  3,  2,  8,  9]])

# %%
np.sort(arr, axis =1, kind ='margesort')
# Out:
# array([[ 2,  3, 32, 45, 56],
#        [ 2,  4,  5,  7,  8],
#        [ 2,  3,  6,  8,  9]])

# %%
arr2 = np.sort(arr, axis =1, kind ='margesort')

# %%
np.sort(arr2, axis =0,kind='stable')
# Out:
# array([[ 2,  3,  5,  7,  8],
#        [ 2,  3,  6,  8,  9],
#        [ 2,  4, 32, 45, 56]])
